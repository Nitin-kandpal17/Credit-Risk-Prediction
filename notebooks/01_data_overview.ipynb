# %% [markdown]
# # CREDIT RISK PREDICTION - DAY 1: Problem Understanding

# %% [markdown]
# ### 1. Project Overview
# **Objective:** Predict whether a loan applicant is likely to default using credit-related features.
#
# **Dataset:** LendingClub Loan Data or Kaggle’s Credit Risk Dataset
#
# **Target Variable:** Loan Status (1 = Default, 0 = Paid)
#
# **Tasks:**
# - ✔ Load dataset
# - ✔ Understand structure
# - ✔ Identify target and useful features
# - ✔ Summarize dataset for reporting

# %%
# 2. Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# 3. Load Dataset
df = pd.read_csv('../data/credit_risk_dataset.csv')

# %%
# 4. Basic Overview
print("🔍 Dataset Shape:", df.shape)
print("\n🔎 First 5 Rows:")
display(df.head())

print("\n🧾 Data Types:")
print(df.dtypes)

print("\n📊 Null Value Count:")
print(df.isnull().sum().sort_values(ascending=False).head(10))
# Out:
# 🔍 Dataset Shape: (32581, 12)
#
# 🔎 First 5 Rows:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0    PERSONAL          D      35000          16.02            1
# 1   EDUCATION          B       1000          11.14            0
# 2     MEDICAL          C       5500          12.87            1
# 3     MEDICAL          C      35000          15.23            1
# 4     MEDICAL          C      35000          14.27            1
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# ...

# %%
# 5. Target Variable Check
# Let's assume 'loan_status' is the target
if 'loan_status' in df.columns:
    print("\n✅ Target column ('loan_status') found.")
    print(df['loan_status'].value_counts())
    sns.countplot(data=df, x='loan_status')
    plt.title("Loan Status Distribution")
    plt.show()
else:
    print("❌ 'loan_status' column not found. Please verify column name.")
# Out:
# ✅ Target column ('loan_status') found.
# loan_status
# 0    25473
# 1     7108
# Name: count, dtype: int64

# %%
# 6. Basic Stats Summary
print("\n📈 Statistical Summary:")
display(df.describe().T)
# Out:
# 📈 Statistical Summary:
#                               count          mean           std      min  \
# person_age                  32581.0     27.734600      6.348078    20.00
# person_income               32581.0  66074.848470  61983.119168  4000.00
# person_emp_length           31686.0      4.789686      4.142630     0.00
# loan_amnt                   32581.0   9589.371106   6322.086646   500.00
# loan_int_rate               29465.0     11.011695      3.240459     5.42
# loan_status                 32581.0      0.218164      0.413006     0.00
# loan_percent_income         32581.0      0.170203      0.106782     0.00
# cb_person_cred_hist_length  32581.0      5.804211      4.055001     2.00
#
#                                  25%       50%       75%         max
# person_age                     23.00     26.00     30.00      144.00
# person_income               38500.00  55000.00  79200.00  6000000.00
# person_emp_length               2.00      4.00      7.00      123.00
# ...

# %%
# 7. Save Dataset Summary
summary = {
    "Total Rows": df.shape[0],
    "Total Columns": df.shape[1],
    "Target Column": "loan_status",
    "Missing Values": df.isnull().sum().sum(),
    "Numerical Columns": df.select_dtypes(include=np.number).shape[1],
    "Categorical Columns": df.select_dtypes(include='object').shape[1]
}

summary_df = pd.DataFrame(list(summary.items()), columns=["Metric", "Value"])
summary_df.to_csv("../reports/dataset_summary.csv", index=False)

print("\n✅ Dataset summary saved to 'reports/dataset_summary.csv'")
# Out:
# ✅ Dataset summary saved to 'reports/dataset_summary.csv'
